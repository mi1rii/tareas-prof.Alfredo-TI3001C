# %% [markdown]
# # Actividad 3 (Segmentación)
# - Miranda Eugenia Colorado Arróniz A01737027
# - Ciudad escogida: Hawaii

# %% [markdown]
# ## Inciso c)
# ### K= 5, Variables = “price”, “review_scores_value” y “review_scores_location”

# %%
# Librerías
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
# Convertir el dataset en un dataframe
df= pd.read_csv("listings_filtrado.csv")
df

# Sustituir los valores nulos por los no nulos hacia adelante
df = df.fillna(method="ffill")

# Limpiar la columna 'price' para quitar el símbolo de dólar y convertir a float
df['price'] = df['price'].replace('[\$,]', '', regex=True).astype(float)

# Ahora selecciona las columnas para clustering
X = df[['price', 'review_scores_value', 'review_scores_location']].values
X
# Out:
# <>:9: SyntaxWarning: invalid escape sequence '\$'
# <>:9: SyntaxWarning: invalid escape sequence '\$'
# /var/folders/qg/1b6k32sd5_d2jr8q3bhrhg1r0000gn/T/ipykernel_36549/1234685164.py:9: SyntaxWarning: invalid escape sequence '\$'
#   df['price'] = df['price'].replace('[\$,]', '', regex=True).astype(float)
# /var/folders/qg/1b6k32sd5_d2jr8q3bhrhg1r0000gn/T/ipykernel_36549/1234685164.py:6: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method="ffill")
# array([[ 128.  ,    4.85,    5.  ],
#        [  97.  ,    4.78,    4.74],
#        [ 117.  ,    4.78,    4.74],
#        ...,
#        [  80.  ,    5.  ,    5.  ],
#        [ 102.  ,    5.  ,    5.  ],
#        [1746.  ,    5.  ,    5.  ]], shape=(36125, 3))

# %%
# Escalamos o Normalizamos los datos 
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
#Aplicamos K-means con 5 clusters
kmeans = KMeans(n_clusters=5, random_state=42)
kmeans
# Out:
# KMeans(n_clusters=5, random_state=42)

# %%
#Entrenamos el modelo
etiquetas = kmeans.fit_predict(X_scaled)
etiquetas
# Out:
# array([0, 0, 0, ..., 0, 0, 0], shape=(36125,), dtype=int32)

# %%
#Obtenemos los centroides finales del modelo K-means
centroides = kmeans.cluster_centers_
centroides
# Out:
# array([[-0.03331802,  0.4308362 ,  0.27718173],
#        [ 0.01577288, -3.5854152 , -5.08152476],
#        [14.03291822, -0.01862656, -0.08567033],
#        [ 0.02208141, -3.61516621, -0.24943645],
#        [-0.09216565, -0.56770453, -0.29906874]])

# %%
# Eliminar la columna 'cluster_2D' si ya existe
if 'cluster_3D' in df.columns:
    df.drop('cluster_3D', axis=1, inplace=True)

# Agregamos la columna cluster_3D con las etiquetas obtenidas en una posición específica
df.insert(loc=1, column='cluster_3D', value= etiquetas)
df
# Out:
#                         id  cluster_3D  \
# 0                     5269           0
# 1                     5387           0
# 2                     5480           0
# 3                     5532           0
# 4                     7888           4
# ...                    ...         ...
# 36120  1369817596570977772           0
# 36121  1369824863578661367           0
# 36122  1369841764486904562           0
# 36123  1369865927101822261           0
# 36124  1369922190115798307           0
#
#                                             listing_url  \
# 0                     https://www.airbnb.com/rooms/5269
# 1                     https://www.airbnb.com/rooms/5387
# 2                     https://www.airbnb.com/rooms/5480
# 3                     https://www.airbnb.com/rooms/5532
# 4                     https://www.airbnb.com/rooms/7888
# ...                                                 ...
# 36120  https://www.airbnb.com/rooms/1369817596570977772
# 36121  https://www.airbnb.com/rooms/1369824863578661367
# 36122  https://www.airbnb.com/rooms/1369841764486904562
# 36123  https://www.airbnb.com/rooms/1369865927101822261
# 36124  https://www.airbnb.com/rooms/1369922190115798307
#
#                                                     name  \
# 0              Upcountry Hospitality in the 'Auwai Suite
# 1                    Hale Koa Studio & 1 Bedroom Units!!
# 2                     Isle Of You Naturally Farm Retreat
# 3      2BR Waialua Beach Condo w/ Saltwater Pool & Sauna
# 4      Pineapple House 2 Bed 1 Bath with Loft Entire ...
# ...                                                  ...
# 36120                     1212 - 1B2OV The Whaler Resort
# 36121                       MRR: 9BR Luana Garden Villas
# 36122                   1-br MIL apartment in Wilhelmina
# 36123                                      Camping Cheap
# 36124                   1202 - 2BOFP - The Whaler Resort
#
#                                    neighborhood_overview  \
# 0      We are located on the "sunny side" of Waimea, ...
# 1      IN a Farm belt area with small commercial farm...
# 2      We are located on a rural one lane road going ...
# 3      We are located on a rural one lane road going ...
# 4      We are located on a rural one lane road going ...
# ...                                                  ...
# 36120  ONE BLOCK FROM THE BEACH AND ZOO. <br /><br />...
# 36121  When it is time to leave the resort, Honua Kai...
# 36122  Wilhelmina Rise overlooks Kaimuki and Kahala. ...
# 36123  Wilhelmina Rise overlooks Kaimuki and Kahala. ...
# 36124  Wilhelmina Rise overlooks Kaimuki and Kahala. ...
#
#                                              picture_url    host_id  \
# 0      https://a0.muscache.com/pictures/5b52b72f-5a09...       7620
# 1      https://a0.muscache.com/pictures/1170713/dca6a...       7878
# 2      https://a0.muscache.com/pictures/75530989/8ed3...       8145
# 3      https://a0.muscache.com/pictures/13743/134691a...       8279
# 4      https://a0.muscache.com/pictures/hosting/Hosti...      22083
# ...                                                  ...        ...
# 36120  https://a0.muscache.com/pictures/prohost-api/H...  529290529
# 36121  https://a0.muscache.com/pictures/prohost-api/H...   39073224
# 36122  https://a0.muscache.com/pictures/miso/Hosting-...   19796174
# 36123  https://a0.muscache.com/pictures/miso/Hosting-...  595524064
# 36124  https://a0.muscache.com/pictures/prohost-api/H...  529290529
#
#                                           host_url        host_name  \
# 0           https://www.airbnb.com/users/show/7620        Lea & Pat
# 1           https://www.airbnb.com/users/show/7878           Edward
# 2           https://www.airbnb.com/users/show/8145          Normand
# 3           https://www.airbnb.com/users/show/8279           Sarada
# 4          https://www.airbnb.com/users/show/22083           Steven
# ...                                            ...              ...
# 36120  https://www.airbnb.com/users/show/529290529       The Whaler
# 36121   https://www.airbnb.com/users/show/39073224  Matthew William
# 36122   https://www.airbnb.com/users/show/19796174           Marina
# 36123  https://www.airbnb.com/users/show/595524064          Brandon
# 36124  https://www.airbnb.com/users/show/529290529       The Whaler
#
#        host_since  ... review_scores_cleanliness review_scores_checkin  \
# 0      2009-02-09  ...                      4.55                  4.95
# 1      2009-02-13  ...                      4.42                  4.85
# 2      2009-02-18  ...                      4.42                  4.85
# 3      2009-02-20  ...                      4.42                  4.85
# 4      2009-06-17  ...                      4.70                  4.79
# ...           ...  ...                       ...                   ...
# 36120  2023-08-01  ...                      5.00                  5.00
# 36121  2015-07-20  ...                      5.00                  5.00
# 36122  2014-08-10  ...                      5.00                  5.00
# 36123  2024-08-11  ...                      5.00                  5.00
# 36124  2023-08-01  ...                      5.00                  5.00
#
#       review_scores_communication review_scores_location review_scores_value  \
# 0                            4.85                   5.00                4.85
# 1                            4.88                   4.74                4.78
# 2                            4.88                   4.74                4.78
# 3                            4.88                   4.74                4.78
# 4                            4.76                   4.25                4.60
# ...                           ...                    ...                 ...
# 36120                        5.00                   5.00                5.00
# 36121                        5.00                   5.00                5.00
# 36122                        5.00                   5.00                5.00
# 36123                        5.00                   5.00                5.00
# 36124                        5.00                   5.00                5.00
#
#       instant_bookable  calculated_host_listings_count  \
# 0                    f                               3
# 1                    t                               2
# 2                    f                               3
# 3                    f                               1
# 4                    f                               1
# ...                ...                             ...
# 36120                t                              61
# 36121                t                             548
# 36122                f                               1
# 36123                f                               1
# 36124                t                              61
#
#       calculated_host_listings_count_entire_homes  \
# 0                                               3
# 1                                               2
# 2                                               0
# 3                                               1
# 4                                               1
# ...                                           ...
# 36120                                          61
# 36121                                         540
# 36122                                           1
# 36123                                           1
# 36124                                          61
#
#       calculated_host_listings_count_private_rooms  \
# 0                                                0
# 1                                                0
# 2                                                3
# 3                                                0
# 4                                                0
# ...                                            ...
# 36120                                            0
# 36121                                            8
# 36122                                            0
# 36123                                            0
# 36124                                            0
#
#        calculated_host_listings_count_shared_rooms
# 0                                                0
# 1                                                0
# 2                                                0
# 3                                                0
# 4                                                0
# ...                                            ...
# 36120                                            0
# 36121                                            0
# 36122                                            0
# 36123                                            0
# 36124                                            0
#
# [36125 rows x 51 columns]

# %%
# Reducimos a 2 dimensiones
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)
centroides_pca=pca.fit_transform(centroides)

# %%
# Para visualizar en 4D, Se reduce a 2 dimensiones 
plt.figure(figsize=(8, 5))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=etiquetas, cmap='viridis', s=50)
plt.scatter(centroides_pca[:, 0], centroides_pca[:, 1], c='red', marker='.', s=200, label='Centroides')

# “price”, “review_scores_value” y “review_scores_location”
plt.title("Clustering por 'price', 'review_scores_value' y 'review_scores_location'")
plt.xlabel("Componente principal 1")
plt.ylabel("Componente principal 2")
plt.legend()
plt.grid(True)
plt.show()
